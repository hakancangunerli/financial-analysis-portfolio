# %%
import quantstats as qs
import pandas as pd

# %%
# UBS 
# Credit Suisse (CS)

# %%
cs = qs.utils.download_returns('CS')
qs.reports.full(cs.tz_localize(None,ambiguous='infer'))
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               1995-05-16
# End Period                 2023-03-17
# Risk-Free Rate             0.0%
# Time in Market             94.0%
#
# Cumulative Return          -82.31%
# CAGR﹪                     -6.03%
#
# Sharpe                     0.05
# Prob. Sharpe Ratio         60.85%
# Smart Sharpe               0.05
# Sortino                    0.07
# Smart Sortino              0.07
# Sortino/√2                 0.05
# Smart Sortino/√2           0.05
# Omega                      1.01
#
# Max Drawdown               -95.76%
# Longest DD Days            5804
# Volatility (ann.)          40.78%
# Calmar                     -0.06
# Skew                       -0.07
# Kurtosis                   8.84
#
# Expected Daily %           -0.02%
# Expected Monthly %         -0.52%
# Expected Yearly %          -5.8%
# Kelly Criterion            0.5%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -4.22%
# Expected Shortfall (cVaR)  -4.22%
#
# Max Consecutive Wins       11
# Max Consecutive Losses     11
# Gain/Pain Ratio            0.01
# Gain/Pain (1M)             0.05
#
# Payoff Ratio               1.0
# Profit Factor              1.01
# Common Sense Ratio         1.02
# CPC Index                  0.51
# Tail Ratio                 1.01
# Outlier Win Ratio          4.58
# Outlier Loss Ratio         4.23
#
# MTD                        -34.53%
# 3M                         -34.74%
# 6M                         -61.57%
# YTD                        -33.88%
# 1Y                         -74.41%
# 3Y (ann.)                  -36.07%
# 5Y (ann.)                  -33.49%
# 10Y (ann.)                 -20.69%
# All-time (ann.)            -6.03%
#
# Best Day                   23.44%
# Worst Day                  -20.91%
# Best Month                 37.98%
# Worst Month                -34.53%
# Best Year                  74.39%
# Worst Year                 -67.96%
#
# Avg. Drawdown              -7.81%
# Avg. Drawdown Days         184
# Recovery Factor            -0.86
# Ulcer Index                0.52
# Serenity Index             -0.05
#
# Avg. Up Month              7.47%
# Avg. Down Month            -8.05%
# Win Days %                 50.14%
# Win Month %                51.95%
# Win Quarter %              58.04%
# Win Year %                 41.38%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2007-04-26  2023-03-17  2023-03-17  5804    -95.763672        -93.255597
# 2  1998-07-31  2002-10-09  2006-01-26  2736    -77.351457        -70.923064
# 3  2006-05-11  2006-06-13  2006-11-07   180    -21.618659        -19.990606
# 4  1996-01-09  1996-06-07  1996-07-02   175    -20.772955        -18.840588
# 5  1997-07-10  1997-08-27  1997-10-03    85    -17.073174        -17.073174
# <h4>Strategy Visualization</h4>

# %%
ubs = qs.utils.download_returns('UBS')
qs.reports.full(ubs.tz_localize(None,ambiguous='infer'))
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2000-05-16
# End Period                 2023-03-17
# Risk-Free Rate             0.0%
# Time in Market             99.0%
#
# Cumulative Return          8.21%
# CAGR﹪                     0.35%
#
# Sharpe                     0.2
# Prob. Sharpe Ratio         83.69%
# Smart Sharpe               0.2
# Sortino                    0.3
# Smart Sortino              0.28
# Sortino/√2                 0.21
# Smart Sortino/√2           0.2
# Omega                      1.04
#
# Max Drawdown               -89.06%
# Longest DD Days            5803
# Volatility (ann.)          39.4%
# Calmar                     0.0
# Skew                       0.71
# Kurtosis                   21.59
#
# Expected Daily %           0.0%
# Expected Monthly %         0.03%
# Expected Yearly %          0.33%
# Kelly Criterion            2.05%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -4.05%
# Expected Shortfall (cVaR)  -4.05%
#
# Max Consecutive Wins       11
# Max Consecutive Losses     11
# Gain/Pain Ratio            0.04
# Gain/Pain (1M)             0.22
#
# Payoff Ratio               1.02
# Profit Factor              1.04
# Common Sense Ratio         1.07
# CPC Index                  0.54
# Tail Ratio                 1.02
# Outlier Win Ratio          4.53
# Outlier Loss Ratio         4.76
#
# MTD                        -16.44%
# 3M                         2.54%
# 6M                         10.77%
# YTD                        -2.52%
# 1Y                         3.48%
# 3Y (ann.)                  31.4%
# 5Y (ann.)                  4.23%
# 10Y (ann.)                 3.96%
# All-time (ann.)            0.35%
#
# Best Day                   32.69%
# Worst Day                  -22.64%
# Best Month                 44.64%
# Worst Month                -29.56%
# Best Year                  41.29%
# Worst Year                 -68.91%
#
# Avg. Drawdown              -4.88%
# Avg. Drawdown Days         122
# Recovery Factor            0.09
# Ulcer Index                0.6
# Serenity Index             0.0
#
# Avg. Up Month              6.76%
# Avg. Down Month            -7.13%
# Win Days %                 50.57%
# Win Month %                54.55%
# Win Quarter %              54.35%
# Win Year %                 62.5%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2007-04-27  2009-03-09  2023-03-17  5803    -89.055178        -84.504913
# 2  2001-02-01  2002-10-07  2003-07-25   904    -41.341640        -34.429670
# 3  2000-08-18  2000-10-18  2000-12-11   115    -20.815665        -19.752039
# 4  2006-05-09  2006-07-18  2006-10-10   154    -20.071737        -19.484744
# 5  2004-02-18  2004-08-09  2004-11-12   268    -18.056787        -17.577289
# <h4>Strategy Visualization</h4>

# %%
# analysis of ubs first 

# sharpe ration: 
''''The Sharpe ratio divides a portfolio's excess returns by a measure of its volatility to assess risk-adjusted performance'''

'''
A higher Sharpe ratio indicates that an investment or portfolio is providing a higher return relative to its risk, and is therefore more attractive. Conversely, a lower Sharpe ratio indicates that an investment or portfolio is providing a lower return relative to its risk, and is therefore less attractive.
'''

print(qs.stats.sharpe(ubs), 'sharpe ratio')

# avg loss
print(qs.stats.avg_loss(ubs), 'avg loss') # avg loss

# avg gain
print(qs.stats.avg_win(ubs), 'avg gain') # avg gain

# win-loss ratio 
print(qs.stats.win_loss_ratio(ubs), 'win loss ratio') # win/loss which means the higher it is the better


# distribution 

print(qs.plots.log_returns(ubs))

print(qs.plots.histogram(ubs))
# Out:
# 0.2047649064926175 sharpe ratio
# -0.015480267773565728 avg loss
# 0.01577060956532038 avg gain
# 1.018755605264816 win loss ratio
# None
# None

# %%
# analysis of ubs first 

# sharpe ration: 
''''The Sharpe ratio divides a portfolio's excess returns by a measure of its volatility to assess risk-adjusted performance'''

'''
A higher Sharpe ratio indicates that an investment or portfolio is providing a higher return relative to its risk, and is therefore more attractive. Conversely, a lower Sharpe ratio indicates that an investment or portfolio is providing a lower return relative to its risk, and is therefore less attractive.
'''

print(qs.stats.sharpe(cs), 'sharpe ratio')

# avg loss
print(qs.stats.avg_loss(cs), 'avg loss') # avg loss

# avg gain
print(qs.stats.avg_win(cs), 'avg gain') # avg gain

# win-loss ratio 
print(qs.stats.win_loss_ratio(cs), 'win loss ratio') # win/loss which means the higher it is the better


# distribution 

print(qs.plots.log_returns(cs))

print(qs.plots.histogram(cs))
# Out:
# 0.05223209489729753 sharpe ratio
# -0.017968213276398772 avg loss
# 0.018049823308095736 avg gain
# 1.0045419113431917 win loss ratio
# None
# None

# %%
# win_loss_ratio for ubs, cs

print(qs.stats.win_loss_ratio(ubs))

print(qs.stats.win_loss_ratio(cs))
# Out:
# 1.018755605264816
# 1.0045419113431917
